# %% [markdown]
# # 01 - EDA
#
# Notebook da Etapa 4 (EDA orientada a decisão).
#
# Este notebook utiliza o pipeline reproduzível em `src.eda.run_eda`.

# %%
from src.eda.run_eda import run_eda_pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.eda.run_eda import run_eda_pipeline
#
# ModuleNotFoundError: No module named 'src'

# %%
result = run_eda_pipeline()
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = run_eda_pipeline()
#       2 result
#
# NameError: name 'run_eda_pipeline' is not defined

# %% [markdown]
# ## Artefatos esperados
#
# - `reports/eda_report.md`
# - `reports/figures/eda_target_distribution.png`
# - `reports/figures/eda_ciclos_por_hora.png`
# - `reports/figures/eda_top_frotas.png`
# - `reports/figures/eda_duracao_ciclo_hist.png`
# - `reports/figures/eda_top_classes.png`
