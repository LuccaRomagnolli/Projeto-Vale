# %% [markdown]
# # 01 - Business Understanding (Executivo + Técnico)
#
# Notebook de abertura para o Head de Tecnologia: problema, objetivo, KPI oficial e critérios de aceite.
#
# ## Problema de negócio
# - Operação de mina com risco de alertas críticos (Don't Go).
# - Necessidade de antecipar risco para priorizar inspeções.
# - Decisão diária limitada por capacidade operacional.
#
# ## Pergunta analítica principal
# **Quais equipamentos têm maior risco de gerar alerta crítico nas próximas 4 horas?**
#
# ## Scorecard oficial
# - Primárias: `Precision@TopK Tag-dia`, `Recall@TopK Tag-dia`, `Lift@TopK Tag-dia`
# - Secundárias: `AUC-PR`, `Recall`, `Precision`, `AUC-ROC` ciclo-a-ciclo

# %%
from pathlib import Path

ROOT = Path.cwd().resolve().parents[0]
print('Projeto:', ROOT)
print('Arquivos críticos:')
for p in [
    ROOT / 'README.md',
    ROOT / 'docs' / 'benchmark_modelos_recomendacoes.md',
    ROOT / 'docs' / 'politica_promocao_modelo.md',
]:
    print('-', p.name, '=>', p.exists())
# Out:
# Projeto: /Users/luccaromagnolli/Desktop/Projeto Vale
# Arquivos críticos:
# - README.md => True
# - benchmark_modelos_recomendacoes.md => True
# - politica_promocao_modelo.md => True

# %% [markdown]
# # 01 - Business Understanding
#
# Este notebook contextualiza o problema e define o critério de sucesso operacional.

# %% [markdown]
# ## Objetivo do projeto
# - Antecipar alertas **Don't Go** com janela de 4 horas.
# - Priorizar a fila diária de inspeções por risco.
# - Reduzir paradas não planejadas e riscos de segurança.

# %% [markdown]
# ## Pergunta analítica principal
# **Quais equipamentos têm maior risco de gerar alerta crítico nas próximas 4 horas, dado o padrão atual de operação?**
#
# Use este notebook para explicar o contexto para stakeholders não técnicos.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[0]
print('Projeto:', PROJECT_ROOT)
print('Docs disponíveis:')
for path in sorted((PROJECT_ROOT / 'docs').glob('etapa_*.md')):
    print('-', path.name)
# Out:
# Projeto: /Users/luccaromagnolli/Desktop/Projeto Vale
# Docs disponíveis:
# - etapa_10_avaliacao_segmentada.md
# - etapa_1_fundacao_engenharia.md
# - etapa_2_ingestao_contrato_dados.md
# - etapa_3_rotulacao_alert_labeler.md
# - etapa_4_eda_orientada_decisao.md
# - etapa_5_feature_engineering.md
# - etapa_6_validacao_temporal_baseline.md
# - etapa_7_modelo_principal.md
# - etapa_8_otimizacao_metricas_hist_gbdt.md
# - etapa_9_metricas_operacionais_confiaveis.md
