# %% [markdown]
# # 02 - Data Preparation
#
# Objetivo: limpeza, features e rotulagem inicial (CM 3).

# %%
from projeto_vale.features import build_apontamentos_features
from projeto_vale.io import load_alarm_rules
from projeto_vale.rules import apply_critical_rules

REGRAS='Base de Dados/Alarmes - Regra de Negocio.xlsx'

# %%
rules = load_alarm_rules(REGRAS)
features = build_apontamentos_features(ap)
labeled_tel = apply_critical_rules(tel, rules)
features.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rules = load_alarm_rules(REGRAS)
#       2 features = build_apontamentos_features(ap)
#       3 labeled_tel = apply_critical_rules(tel, rules)
#       4 features.head()
#
# File ~/Desktop/Projeto Vale/src/projeto_vale/io.py:94, in load_alarm_rules(path)
#      92 """Carrega todas as regras da planilha e concatena abas validas."""
#      93 path = Path(path)
# ---> 94 xls = pd.ExcelFile(path)
#      96 frames: list[pd.DataFrame] = []
#      97 for sheet in xls.sheet_names:
#
# File ~/Desktop/Projeto Vale/.venv/lib/python3.13/site-packages/pandas/io/excel/_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
# ...
