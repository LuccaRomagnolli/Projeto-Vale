# %% [markdown]
# # 04 - Evaluation and Interpretability
#
# Objetivo: metricas, matriz de confusao e curvas (CM 5).

# %%
from projeto_vale.evaluate import compute_classification_metrics, save_roc_pr_curves, save_confusion_matrix_plot

metrics = compute_classification_metrics(val_df['target_critical_4h'], val_prob)
metrics

# %%
save_roc_pr_curves(val_df['target_critical_4h'], val_prob, 'reports/figures')
save_confusion_matrix_plot(val_df['target_critical_4h'], val_prob, 'reports/figures/confusion_matrix.png')
